# %% [markdown]
# <a href="https://colab.research.google.com/github/zeeros/MDSForensicsChallenge/blob/master/Deconvolution_with_Wiener_filter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import time

from skimage import color, data, restoration
from scipy.signal import convolve2d as conv2


img = color.rgb2gray(mpimg.imread('/content/drive/My Drive/Colab Notebooks/img/lab1/Cameras/Canon600D/canon_04.jpg'))
psf = np.ones((5, 5)) / 5**2
#img = conv2(img, psf, 'same')
#img += 0.1 * img.std() * np.random.standard_normal(img.shape)
#img_w, _ = restoration.unsupervised_wiener(img, psf)
img_w = restoration.wiener(img, psf, 1100)

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(14, 5), sharex=True, sharey=True)

plt.gray()

ax[0].imshow(img, vmin=img_w.min(), vmax=img_w.max())
ax[0].axis('off')
ax[0].set_title('Original image')

ax[1].imshow(img_w)
ax[1].axis('off')
ax[1].set_title('Wiener filter')

fig.tight_layout()
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
